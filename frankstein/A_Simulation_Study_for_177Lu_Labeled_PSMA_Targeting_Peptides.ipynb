# %% [markdown]
# [Like to the paper](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5017739/pdf/pone.0162303.pdf)

# %%
import pandas as pd

# Creating the DataFrame for Table 1
data = {
    'Patient': ['P1', 'P2', 'P3', 'P4', 'P5', 'Mean', 'SD'],
    'Age': [76, 69, 78, 54, 53, 66, 12],
    'BSA [m2]': [2.0, 1.9, 1.8, 2.1, 2.0, 2.0, 0.1],
    'Amounta [nmol]': [148, 98, 89, 74, 302, 142, 94],
    'Activity [GBq]': [6.0, 5.4, 5.4, 5.4, 5.6, 5.6, 0.3],
    'TER [ml/min]': [198, 201, 136, 252, 176, 193, 42],
    'Parotid glands [ml]': [54, 21, 17, 52, 29, 35, 17],
    'Kidneys [ml]': [321, 311, 394, 268, 296, 318, 47],
    'Tumor 1 [ml]': [0.5, 1, 2, 4, 1.5, 6, None],
    'Tumor 2 [ml]': [1, 34, 13, 3, 1, None, 10]
}

df_patient_info = pd.DataFrame(data)
df_patient_info
# Out:
#   Patient  Age  BSA [m2]  Amounta [nmol]  Activity [GBq]  TER [ml/min]  \
# 0      P1   76       2.0             148             6.0           198
# 1      P2   69       1.9              98             5.4           201
# 2      P3   78       1.8              89             5.4           136
# 3      P4   54       2.1              74             5.4           252
# 4      P5   53       2.0             302             5.6           176
# 5    Mean   66       2.0             142             5.6           193
# 6      SD   12       0.1              94             0.3            42
#
#    Parotid glands [ml]  Kidneys [ml]  Tumor 1 [ml]  Tumor 2 [ml]
# 0                   54           321           0.5           1.0
# 1                   21           311           1.0          34.0
# 2                   17           394           2.0          13.0
# 3                   52           268           4.0           3.0
# 4                   29           296           1.5           1.0
# ...
