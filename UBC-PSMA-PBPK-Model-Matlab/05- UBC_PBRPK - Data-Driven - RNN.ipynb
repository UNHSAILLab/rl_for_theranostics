# %% [markdown]
# # Data-driven PBRPK for Theranostics - Regression Model
# Author: Binesh Sadanandan
# Date created: 2024/09
# Description: In this study, we are trying to model a data driven PBPK model based on https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10803696/

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
import sys
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.width', 3000)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
file_path='/Users/tbin/Documents/GitHub/W2df_trans_sim_w8.csv'
df_transf=pd.read_csv(file_path)

# %%
df_transf.columns
# Out:
# Index(['Unnamed: 0', 'Tumor2Vas_species_Hot', 'Tumor2Vas_species_Cold', 'Tumor2Vas_species_AlbHot', 'Tumor2Vas_species_AlbCold', 'Tumor2_species_R', 'Tumor2Int_species_Hot', 'Tumor2Int_species_Cold', 'Tumor2Int_species_AlbHot', 'Tumor2Int_species_AlbCold',
#        ...
#        'observable_TIA_Kidney', 'observable_TIA_SG', 'observable_TIA_Liver', 'observable_TIA_Spleen', 'observable_TIA_RedMarrow', 'observable_HotStuffBlood', 'observable_BloodTIA', 'observable_repeatInterval', 'observable_repeatdose', 'FileName'], dtype='object', length=198)

# %%
df_transf[df_transf['FileName']=='SimDataResults_4473.csv']
# Out:
#     Unnamed: 0  Tumor2Vas_species_Hot  Tumor2Vas_species_Cold  Tumor2Vas_species_AlbHot  Tumor2Vas_species_AlbCold  Tumor2_species_R  Tumor2Int_species_Hot  Tumor2Int_species_Cold  Tumor2Int_species_AlbHot  Tumor2Int_species_AlbCold  Tumor2Bound_species_Hot  Tumor2Bound_species_Cold  Tumor2Intern_species_Hot  Tumor2Intern_species_Cold  Art_species_Hot  Art_species_Cold  Art_species_AlbHot  Art_species_AlbCold  Vein_species_Hot  Vein_species_Cold  Vein_species_AlbHot  Vein_species_AlbCold  Tumor1_species_R  Tumor1Vas_species_Hot  Tumor1Vas_species_Cold  Tumor1Vas_species_AlbHot  Tumor1Vas_species_AlbCold  Tumor1Int_species_Hot  Tumor1Int_species_Cold  Tumor1Int_species_AlbHot  Tumor1Int_species_AlbCold  Tumor1Bound_species_Hot  Tumor1Bound_species_Cold  Tumor1Intern_species_Hot  Tumor1Intern_species_Cold  Kidney_species_R  KidneyVas_species_Hot  KidneyVas_species_Cold  KidneyVas_species_AlbHot  KidneyVas_species_AlbCold  KidneyInt_species_Hot  KidneyInt_species_Cold  KidneyBound_speci
# ...
